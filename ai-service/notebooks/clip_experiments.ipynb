# %% [markdown]
# # ReBloom CLIP Experiments
#
# Use this notebook for image/text embedding experiments. The production app does not depend on this notebook.

# %%
from pathlib import Path

BASE_DIR = Path('..').resolve()
DATA_PATH = BASE_DIR / 'data' / 'products.csv'
DATA_PATH
